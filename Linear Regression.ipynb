# %% [markdown]
# ### Linear Regression and MultiOutputRegressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd

# %%
data=pd.read_excel(r"D:\Practice\FO Incentive 2.xlsx")

# %% [markdown]
# #### EDA (Exploratory Data Analysis)

# %%
#data.info()

# %%
# Convert Data type
data["RO ID"]=data["RO ID"].astype('object')

# %%
#data.describe()

# %%
# Seprate Numercial & Text Columns
Numerical_Columns=Incentive_data.select_dtypes(include=["int" ,"float"])
Object_Columns=Incentive_data.select_dtypes("object")

# %%
X = data[['Loans in Demand', 'Caluclated Fuel', 'Disb Count', 'Fuel of Disb','Total Fuel', 'Working Day',]]  # Note the double brackets → this keeps it as a DataFrame (2D)
y = data['Paid Days Fuel']

# %%
# Split Data in Train & Text Size
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=54)

# %%
# apply model and fit on it Data
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Predict Value
y_pred = model.predict(X_test)

# %%
# check accuracy of output / Predict value
accuracy = mean_absolute_error(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 54.47280183813405

# %%
# Find error in your model/Evaluate Errors
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)
print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# MAE: 54.47
# MSE: 7337.19
# RMSE: 85.66
# R-squared: 0.99

# %%
# Take input from users
loans = float(input("Enter Loans in Demand: "))
calculated_fuel = float(input("Enter Calculated Fuel: "))
disb_count = int(input("Enter Disb Count: "))
fuel_disb = float(input("Enter Fuel of Disb: "))
total_fuel = float(input("Enter Total Fuel: "))
working_day = int(input("Enter Working Day: "))
# Out:
# Enter Loans in Demand:  500
# Enter Calculated Fuel:  3000
# Enter Disb Count:  8
# Enter Fuel of Disb:  400
# Enter Total Fuel:  3400
# Enter Working Day:  19

# %%
# Store input in DataFrame
user_input = pd.DataFrame([[
    loans, calculated_fuel, disb_count, fuel_disb, total_fuel, working_day
]], columns=['Loans in Demand', 'Caluclated Fuel', 'Disb Count', 'Fuel of Disb', 'Total Fuel', 'Working Day'])

# %%
# Find output / predict Value
prediction = model.predict(user_input)
print(f"Predicted Paid Days Fuel: {prediction[0]:.2f}")
# Out:
# Predicted Paid Days Fuel: 2510.54

# %% [markdown]
# ### Multiple value predict

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.multioutput import MultiOutputRegressor

# %%
X = data[['Loans in Demand', 'Disb Count', 'Working Day']]
y = data[['Caluclated Fuel', 'Fuel of Disb', 'Total Fuel', 'Paid Days Fuel']]

# %%
X_train,X_test,y_train,y_text=train_test_split(X,y,random_state=43,test_size=0.25)

# %%
model = MultiOutputRegressor(RandomForestRegressor())
model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor())

# %%
loans = float(input("Enter Loans in Demand: "))
disb = int(input("Enter Disb Count: "))
day = int(input("Enter Working Day: "))
# Out:
# Enter Loans in Demand:  656
# Enter Disb Count:  7
# Enter Working Day:  16

# %%
user_input = pd.DataFrame([[
    loans, disb, day
]], columns=['Loans in Demand', 'Disb Count', 'Working Day'])

# %%
prediction = model.predict(user_input)

# %%
output_columns = ['Caluclated Fuel', 'Fuel of Disb', 'Total Fuel', 'Paid Days Fuel']

# %%
for col, value in zip(output_columns, prediction[0]):
    print(f"{col}: {value:.2f}")
# Out:
# Caluclated Fuel: 3000.00
# Fuel of Disb: 350.00
# Total Fuel: 3350.00
# Paid Days Fuel: 1498.48
